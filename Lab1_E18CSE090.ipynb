# %%
import os
import numpy as np
import pandas as pd
#import pydicom
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import PIL

# %%
img = mpimg.imread(r'C:\Users\hp\Pictures\Camera Roll\wow.jpg')
print(img)
# Out:
# [[[180 192 192]
#   [180 192 192]
#   [178 193 190]
#   ...
#   [ 99  89 123]
#   [ 96  89 123]
#   [ 96  89 123]]
#
#  [[180 192 190]
#   [180 192 190]
#   [178 193 188]
#   ...
#   [101  91 125]
#   [ 99  92 125]
#   [ 97  90 124]]
#
#  [[180 191 187]
#   [180 191 187]
#   [179 192 185]
#   ...
#   [102  95 128]
#   [101  94 127]
#   [ 97  92 124]]
#
#  ...
#
#  [[175 126  96]
#   [178 131 101]
#   [175 128  98]
#   ...
#   [ 70  69  64]
#   [ 79  78  73]
#   [ 83  80  75]]
#
#  [[175 126  96]
#   [179 130 100]
#   [177 128  98]
#   ...
#   [ 73  70  65]
#   [ 90  85  79]
#   [ 83  78  72]]
#
#  [[181 132 102]
#   [176 127  97]
#   [175 126  96]
#   ...
#   [ 76  71  65]
#   [ 92  87  81]
#   [ 81  74  68]]]

# %%
print(img.shape)
print("Height of the image:",img.shape[0])
print("Widht of the image:",img.shape[1])
print("No. of channels in image",img.shape[2])
# Out:
# (720, 1280, 3)
# Height of the image: 720
# Widht of the image: 1280
# No. of channels in image 3

# %%
imgplot = plt.imshow(img)
plt.savefig('plt_image',dpi=300, bbox_inches='tight')

# %%
from PIL import Image
img_pil = Image.open(r'C:\Users\hp\Pictures\Camera Roll\wow.jpg')

# %%
pil_width, pil_height = img_pil.size
print("Width of image is:",pil_width)
print("Height of image is:",pil_height)
# Out:
# Width of image is: 1280
# Height of image is: 720

# %%
img_pil
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x720 at 0x19C9C004C88>

# %%
img_pil.save("pil_image.jpg")

# %%
import skimage.io
from skimage.io import imread, imshow

# %%
image_skimage = skimage.io.imread(fname = r'C:\Users\hp\Pictures\Camera Roll\wow.jpg')

# %%
imshow(image_skimage)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# C:\Users\hp\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)

# %%
print(image_skimage.shape)
print("Height of the image:",image_skimage.shape[0])
print("Widht of the image:",image_skimage.shape[1])
print("No. of channels in image",image_skimage.shape[2])
# Out:
# (720, 1280, 3)
# Height of the image: 720
# Widht of the image: 1280
# No. of channels in image 3

# %%
skimage.io.imsave(fname="skimage.jpg", arr=image_skimage)

# %%
raw_img = np.fromfile(R'C:\Users\hp\Downloads\lena_gray.raw', dtype='uint8')

# %%
print(raw_img.shape)
# Out:
# (262144,)

# %%
raw_img = raw_img.reshape(512,512)

# %%
plt.imshow(raw_img)

# %%
raw_img.astype('int8').tofile("saved_raw.raw")
